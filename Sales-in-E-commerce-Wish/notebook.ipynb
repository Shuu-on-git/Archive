# %%
# I am analyzing the dataset about the sales of summer clothes in an e-commerce company.

# %% [markdown]
# ### Importing the dataset

# %%
# importing the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# loading the dataset which is Merchant-Level Data computed_insight_success_of_active_sellers.csv as df_mld
df_mld = pd.read_csv('computed_insight_success_of_active_sellers.csv')

# loading the dataset which is Product-Level Data summer-products-with-rating-and-performance_2020-08.csv as df_pld
df_pld = pd.read_csv('summer-products-with-rating-and-performance_2020-08.csv')

# loading the dataset Unique Categories unique-categories.csv as df_uc
df_uc = pd.read_csv('unique-categories.csv')

# loading the dataset Unique Categories Sorted by count unique-categories.sorted-by-count.csv as df_ucsc
df_ucsc = pd.read_csv('unique-categories.sorted-by-count.csv')

# %%
# displaying the first 5 rows of the dataset df_mld
df_mld.head()
# Out:
#                  merchantid  listedproducts  totalunitssold  \
# 0  5357bcf2bb72c5504882e889               2          120000
# 1  5708773c3c02161b3f8c7900               5          107100
# 2  5417aada4ad3ab27e954b76c               2          100007
# 3  570f3a713a698c14278bb51e               1          100000
# 4  53082ea15aefb07dfe1f2a4f               1          100000
#
#    meanunitssoldperproduct  rating  merchantratingscount  meanproductprices  \
# 0                  60000.0   4.219              320031.0               9.00
# 1                  21420.0   3.934              139223.0               7.76
# 2                  50004.0   4.053              108048.0               8.00
# 3                 100000.0   3.889               19248.0               5.67
# 4                 100000.0   4.036              366898.0               5.00
#
#    meanretailprices  averagediscount  meandiscount  meanproductratingscount  \
# ...

# %%
# displaying the first 5 rows of the dataset df_pld
df_pld.head()
# Out:
#                                                title  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1  SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2  2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3  Hot Summer Cool T-shirt pour les femmes Mode T...
# 4  Femmes Shorts d'été à lacets taille élastique ...
#
#                                           title_orig  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1   Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2  2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3  Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4  Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
#
#   currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# 0            EUR         100               0    3.76            54
# ...

# %%
# displaying the first 5 rows of the dataset df_uc
df_uc.head()
# Out:
#                 tag
# 0  #fashion #shorts
# 1  #fashion #tshirt
# 2        #Sport Bra
# 3   #Summer Clothes
# 4        #top #crop

# %%
# displaying the first 5 rows of the dataset df_ucsc
df_ucsc.head()
# Out:
#    count          keyword
# 0   1321           Summer
# 1   1315  Women's Fashion
# 2   1082          Fashion
# 3    961            Women
# 4    905           Casual
